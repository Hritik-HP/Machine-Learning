# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(
    [[18000,110,189,1400],
    [36000,905,23.4,1800],
    [23000,230,14.0,1300],
    [60000,450,13.5,1500]],
    columns=['col1', 'col2', 'col3', 'col4'])
display(df)
# Out:
#     col1  col2   col3  col4
# 0  18000   110  189.0  1400
# 1  36000   905   23.4  1800
# 2  23000   230   14.0  1300
# 3  60000   450   13.5  1500

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'bar')
df.plot()
# Out:
# <AxesSubplot: >

# %%
#•	Using The maximum absolute scaling
df_max_scaled = df.copy()
for column in df_max_scaled.columns:
    df_max_scaled[column] = df_max_scaled[column]/df_max_scaled[column].abs().max()
display(df_max_scaled)
# Out:
#        col1      col2      col3      col4
# 0  0.300000  0.121547  1.000000  0.777778
# 1  0.600000  1.000000  0.123810  1.000000
# 2  0.383333  0.254144  0.074074  0.722222
# 3  1.000000  0.497238  0.071429  0.833333

# %%
import matplotlib.pyplot as plt
df_max_scaled.plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
#•	Using The min-max feature scaling
df_min_max_scaled = df.copy()
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / df_min_max_scaled[column].max() - df_min_max_scaled[column].min()
print(df_min_max_scaled)
# Out:
#            col1        col2       col3         col4
# 0 -18000.000000 -110.000000 -12.571429 -1299.944444
# 1 -17999.700000 -109.121547 -13.447619 -1299.722222
# 2 -17999.916667 -109.867403 -13.497354 -1300.000000
# 3 -17999.300000 -109.624309 -13.500000 -1299.888889

# %%
import matplotlib.pyplot as plt
df_min_max_scaled.plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
#•	Using The z-score method
df_z_scaled = df.copy()
for column in df_z_scaled.columns:
    df_z_scaled[column] = (df_z_scaled[column] -df_z_scaled[column].mean()) / df_z_scaled[column].std()    
  
# view normalized data   
display(df_z_scaled)
# Out:
#        col1      col2      col3     col4
# 0 -0.865821 -0.895492  1.497903 -0.46291
# 1  0.093242  1.373564 -0.424614  1.38873
# 2 -0.599414 -0.552993 -0.533742 -0.92582
# 3  1.371992  0.074922 -0.539547  0.00000

# %%
df_z_scaled.plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
#  by some random values
import pandas as pd
  
df = pd.DataFrame({'dede':[5,-90,20,300.7],'lele':[19,38,25,45]})

display(df)
# Out:
#     dede  lele
# 0    5.0    19
# 1  -90.0    38
# 2   20.0    25
# 3  300.7    45

# %%
df_max_scaled = df.copy()
column = 'dede'
df_max_scaled[column] = df_max_scaled[column] /df_max_scaled[column].abs().max()
display(df_max_scaled)
# Out:
#        dede  lele
# 0  0.016628    19
# 1 -0.299302    38
# 2  0.066511    25
# 3  1.000000    45

# %%
df_min_max_scaled = df.copy()
  
# apply normalization techniques by Column 1
column = 'dede'
df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
display(df_min_max_scaled)
# Out:
#        dede  lele
# 0  0.243153    19
# 1  0.000000    38
# 2  0.281546    25
# 3  1.000000    45

# %%
df_min_max_scaled['dede'].plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
df_z_scaled = df.copy()
  
# apply normalization technique to Column 1
column = 'dede'
df_z_scaled[column] = (df_z_scaled[column] - df_z_scaled[column].mean()) / df_z_scaled[column].std()    


display(df_z_scaled)
# Out:
#        dede  lele
# 0 -0.320255    19
# 1 -0.884451    38
# 2 -0.231172    25
# 3  1.435877    45

# %%
df_z_scaled['dede'].plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
from sklearn.preprocessing import MinMaxScaler
dms=df.copy()
column = 'dede'
dms[column] = MinMaxScaler().fit_transform(np.array(dms[column]).reshape(-1,1))
display(dms)
# Out:
#        dede  lele
# 0  0.243153    19
# 1  0.000000    38
# 2  0.281546    25
# 3  1.000000    45
